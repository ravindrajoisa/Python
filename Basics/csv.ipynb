# %%
# csv
import csv

with open('file.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age', 'City'])
    writer.writerow(['Ravindra', 40, 'Bangalore'])
    writer.writerow(['Joisa', 70, 'Mangalore'])

with open('file.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Ravindra', '40', 'Bangalore']
# ['Joisa', '70', 'Mangalore']
