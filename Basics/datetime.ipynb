# %%
## datetime
## The datetime module in Python provides classes for manipulating dates and times.

from datetime import datetime, timedelta

now = datetime.now()
print("Current date and time:", now)
# Out:
# Current date and time: 2025-12-07 22:02:09.470796

# %%
yesterday = now - timedelta(days=1)
print("Yesterday's date and time:", yesterday)
# Out:
# Yesterday's date and time: 2025-12-06 22:02:09.470796

# %%
## time
import time
print(time.time())
time.sleep(2)
print("Slept for 2 seconds")
# Out:
# 1765125231.2126336
# Slept for 2 seconds
